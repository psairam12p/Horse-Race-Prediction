# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_90=pd.read_csv(r"D:\final project\horse race\Horse\horses_1990.csv")
df_91=pd.read_csv(r"D:\final project\horse race\Horse\horses_1991.csv")
df_92=pd.read_csv(r"D:\final project\horse race\Horse\horses_1992.csv")
df_93=pd.read_csv(r"D:\final project\horse race\Horse\horses_1993.csv")
df_94=pd.read_csv(r"D:\final project\horse race\Horse\horses_1994.csv")
df_95=pd.read_csv(r"D:\final project\horse race\Horse\horses_1995.csv")
df_96=pd.read_csv(r"D:\final project\horse race\Horse\horses_1996.csv")
df_97=pd.read_csv(r"D:\final project\horse race\Horse\horses_1997.csv")
df_98=pd.read_csv(r"D:\final project\horse race\Horse\horses_1998.csv")
df_99=pd.read_csv(r"D:\final project\horse race\Horse\horses_1999.csv")
df_00=pd.read_csv(r"D:\final project\horse race\Horse\horses_2000.csv")
df_01=pd.read_csv(r"D:\final project\horse race\Horse\horses_2001.csv")
df_02=pd.read_csv(r"D:\final project\horse race\Horse\horses_2002.csv")
df_03=pd.read_csv(r"D:\final project\horse race\Horse\horses_2003.csv")
df_04=pd.read_csv(r"D:\final project\horse race\Horse\horses_2004.csv")
df_05=pd.read_csv(r"D:\final project\horse race\Horse\horses_2005.csv")
df_06=pd.read_csv(r"D:\final project\horse race\Horse\horses_2006.csv")
df_07=pd.read_csv(r"D:\final project\horse race\Horse\horses_2007.csv")
df_08=pd.read_csv(r"D:\final project\horse race\Horse\horses_2008.csv")
df_09=pd.read_csv(r"D:\final project\horse race\Horse\horses_2009.csv")
df_10=pd.read_csv(r"D:\final project\horse race\Horse\horses_2010.csv")
df_11=pd.read_csv(r"D:\final project\horse race\Horse\horses_2011.csv")
df_12=pd.read_csv(r"D:\final project\horse race\Horse\horses_2012.csv")
df_13=pd.read_csv(r"D:\final project\horse race\Horse\horses_2013.csv")
df_14=pd.read_csv(r"D:\final project\horse race\Horse\horses_2014.csv")
df_15=pd.read_csv(r"D:\final project\horse race\Horse\horses_2015.csv")
df_16=pd.read_csv(r"D:\final project\horse race\Horse\horses_2016.csv")
df_17=pd.read_csv(r"D:\final project\horse race\Horse\horses_2017.csv")
df_18=pd.read_csv(r"D:\final project\horse race\Horse\horses_2018.csv")
df_19=pd.read_csv(r"D:\final project\horse race\Horse\horses_2019.csv")
df_20=pd.read_csv(r"D:\final project\horse race\Horse\horses_2020.csv")
# Out:
# C:\Users\sairam\AppData\Local\Temp\ipykernel_4292\2536071539.py:24: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_13=pd.read_csv(r"D:\final project\horse race\Horse\horses_2013.csv")
# C:\Users\sairam\AppData\Local\Temp\ipykernel_4292\2536071539.py:31: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_20=pd.read_csv(r"D:\final project\horse race\Horse\horses_2020.csv")

# %%
df_20.head()
# Out:
#      rid          horseName  age  saddle  decimalPrice  isFav  \
# 0  10312         Waterproof  4.0     9.0      0.076923      0
# 1  10312         Eva's Diva  6.0     7.0      0.444444      1
# 2  10312   Incredible Dream  7.0     5.0      0.019608      0
# 3  10312  Hats Off To Larry  6.0     4.0      0.230769      0
# 4  10312             Taqwaa  7.0     6.0      0.038462      0
#
#        trainerName       jockeyName  position positionL  ...     OR  \
# 0  Shaun Keightley   Brendan Powell         1       NaN  ...    NaN
# 1   Phil Middleton       Mr Sam Lee         2        15  ...  110.0
# 2     Conrad Allen     Joshua Moore         3       5.5  ...    NaN
# 3     Mick Channon   Marc Goldstein         4        10  ...    NaN
# 4     Laura Morgan  Richie McLernon         5       5.5  ...    NaN
#
#          father          mother            gfather  runners    margin  weight  \
# 0      Pour Moi  Laughing Water  Duke Of Marmalade        9  1.199095      66
# ...

# %%
combined_df = pd.concat([df_90,df_91,df_92,df_93,df_94,df_95,df_96,df_97,df_98,df_99,df_00,df_01,df_02,df_03,df_04,df_05,df_06,df_07,df_08,df_09,df_10,df_11,df_12,df_13,df_14,df_15,df_16,df_17,df_18,df_19,df_20], ignore_index=True)

# %%
combined_df
# Out:
#             rid         horseName  age  saddle  decimalPrice  isFav  \
# 0        271018        Combermere  6.0     0.0      0.222222      0
# 1        271018     Royal Battery  6.0     0.0      0.090909      0
# 2        271018           Just So  7.0     0.0      0.029412      0
# 3        271018  Mandraki Shuffle  8.0     0.0      0.090909      0
# 4        271018    Turnberry Dawn  8.0     0.0      0.047619      0
# ...         ...               ...  ...     ...           ...    ...
# 4107310  415090         Beefeater  8.0     6.0      0.030303      0
# 4107311  415090     Aimee's Jewel  4.0    11.0      0.153846      0
# 4107312  415090     Times Ticking  5.0     8.0      0.044053      0
# 4107313  415090      Shadows Cast  8.0     3.0      0.041152      0
# 4107314  415090        Awesome Al  7.0    12.0      0.016393      0
#
#               trainerName        jockeyName  position positionL  ...  OR  \
# 0               R G Frost           J Frost         1       NaN  ... NaN
# ...

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4107315 entries, 0 to 4107314
# Data columns (total 28 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   rid           int64
#  1   horseName     object
#  2   age           float64
#  3   saddle        float64
#  4   decimalPrice  float64
#  5   isFav         int64
#  6   trainerName   object
#  7   jockeyName    object
#  8   position      int64
#  9   positionL     object
#  10  dist          object
#  11  weightSt      int64
#  12  weightLb      int64
#  13  overWeight    float64
#  14  outHandicap   float64
#  15  headGear      object
#  16  RPR           float64
#  17  TR            float64
#  18  OR            float64
#  19  father        object
#  20  mother        object
#  21  gfather       object
#  22  runners       int64
#  23  margin        float64
#  24  weight        int64
#  25  res_win       float64
#  26  res_place     float64
#  27  price         object
# ...

# %%
combined_df.isna().sum()
# Out:
# rid                   0
# horseName             0
# age                 309
# saddle           179168
# decimalPrice          0
# isFav                 0
# trainerName        2850
# jockeyName          125
# position              0
# positionL        783662
# dist            1074385
# weightSt              0
# weightLb              0
# overWeight      4012988
# outHandicap     3994332
# headGear        3119695
# RPR              864877
# TR              1681610
# OR              1795263
# father             1289
# mother             4480
# gfather          119374
# runners               0
# margin                0
# weight                0
# res_win               0
# res_place             0
# price           4012304
# dtype: int64

# %%
combined_df.columns
# Out:
# Index(['rid', 'horseName', 'age', 'saddle', 'decimalPrice', 'isFav',
#        'trainerName', 'jockeyName', 'position', 'positionL', 'dist',
#        'weightSt', 'weightLb', 'overWeight', 'outHandicap', 'headGear', 'RPR',
#        'TR', 'OR', 'father', 'mother', 'gfather', 'runners', 'margin',
#        'weight', 'res_win', 'res_place', 'price'],
#       dtype='object')

# %%
#combined_df.to_csv("Horse_race_predict.csv",index=False)

# %%
df=pd.read_csv(r"D:\jupyter folder\Horse_race_predict.csv")
# Out:
# C:\Users\sairam\AppData\Local\Temp\ipykernel_14740\3032278198.py:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r"D:\jupyter folder\Horse_race_predict.csv")

# %%
df.isna().sum()
# Out:
# rid                   0
# horseName             0
# age                 309
# saddle           179168
# decimalPrice          0
# isFav                 0
# trainerName        2850
# jockeyName          125
# position              0
# positionL        783662
# dist            1074385
# weightSt              0
# weightLb              0
# overWeight      4012988
# outHandicap     3994332
# headGear        3119695
# RPR              864877
# TR              1681610
# OR              1795263
# father             1289
# mother             4480
# gfather          119374
# runners               0
# margin                0
# weight                0
# res_win               0
# res_place             0
# price           4012304
# dtype: int64

# %%
'horseName', 'age', 'decimalPrice', 'isFav',
       'trainerName', 'jockeyName', 'position', 'positionL', 'dist',
       'weightSt', 'weightLb', 'overWeight', 'outHandicap', 'headGear', 'RPR',
       'TR', 'OR', 'father', 'mother', 'gfather', 'runners', 'margin',
       'weight', 'res_win', 'res_place', 'price'

# %%
df_remove_column=df.drop(['rid','saddle','overWeight','outHandicap','headGear','father','mother','gfather','price'],axis=1)

# %%
#df_remove_column.to_csv("Horse_race_predict_remove_columns.csv",index=False)

# %%
df_remove_column.columns
# Out:
# Index(['horseName', 'age', 'decimalPrice', 'isFav', 'trainerName',
#        'jockeyName', 'position', 'positionL', 'dist', 'weightSt', 'weightLb',
#        'RPR', 'TR', 'OR', 'runners', 'margin', 'weight', 'res_win',
#        'res_place'],
#       dtype='object')

# %%
df_remove_column.head()
# Out:
#           horseName  age  decimalPrice  isFav      trainerName  jockeyName  \
# 0        Combermere  6.0      0.222222      0        R G Frost     J Frost
# 1     Royal Battery  6.0      0.090909      0       D H Barons     S Earle
# 2           Just So  7.0      0.029412      0      J D Roberts  S Burrough
# 3  Mandraki Shuffle  8.0      0.090909      0  Oliver Sherwood  M Richards
# 4    Turnberry Dawn  8.0      0.047619      0      T B Hallett  P Richards
#
#    position positionL  dist  weightSt  weightLb    RPR    TR  OR  runners  \
# 0         1       NaN   NaN        11         0  111.0  94.0 NaN       14
# 1         2        10   NaN        11         0  101.0  88.0 NaN       14
# 2         3        15  25.0        10         7   86.0  71.0 NaN       14
# 3         4        20  45.0        11         0   66.0  65.0 NaN       14
# 4         5      dist  75.0        11         0    NaN  45.0 NaN       14
#
#      margin  weight  res_win  res_place
# ...

# %%
df_remove_column.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4107315 entries, 0 to 4107314
# Data columns (total 19 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   horseName     object
#  1   age           float64
#  2   decimalPrice  float64
#  3   isFav         int64
#  4   trainerName   object
#  5   jockeyName    object
#  6   position      int64
#  7   positionL     object
#  8   dist          object
#  9   weightSt      int64
#  10  weightLb      int64
#  11  RPR           float64
#  12  TR            float64
#  13  OR            float64
#  14  runners       int64
#  15  margin        float64
#  16  weight        int64
#  17  res_win       float64
#  18  res_place     float64
# dtypes: float64(8), int64(6), object(5)
# memory usage: 595.4+ MB

# %%
def is_alpha(val):
    if pd.isna(val):
        return False
    return str(val).isalpha()

alpha_rows = df_remove_column['positionL'].apply(is_alpha)

df_cleaned = df_remove_column[~alpha_rows]

# %%
df_cleaned['positionL'] = pd.to_numeric(df_cleaned['positionL'], errors='coerce')
df_cleaned['dist'] = pd.to_numeric(df_cleaned['dist'], errors='coerce')
# Out:
# C:\Users\sairam\AppData\Local\Temp\ipykernel_14740\3755303387.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['positionL'] = pd.to_numeric(df_cleaned['positionL'], errors='coerce')
# C:\Users\sairam\AppData\Local\Temp\ipykernel_14740\3755303387.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['dist'] = pd.to_numeric(df_cleaned['dist'], errors='coerce')

# %%
df_cleaned.head()
# Out:
#           horseName  age  decimalPrice  isFav      trainerName  jockeyName  \
# 0        Combermere  6.0      0.222222      0        R G Frost     J Frost
# 1     Royal Battery  6.0      0.090909      0       D H Barons     S Earle
# 2           Just So  7.0      0.029412      0      J D Roberts  S Burrough
# 3  Mandraki Shuffle  8.0      0.090909      0  Oliver Sherwood  M Richards
# 5         Yreka Bay  8.0      0.029412      0    J A C Edwards    W Irvine
#
#    position  positionL  dist  weightSt  weightLb    RPR    TR  OR  runners  \
# 0         1        NaN   NaN        11         0  111.0  94.0 NaN       14
# 1         2       10.0   NaN        11         0  101.0  88.0 NaN       14
# 2         3       15.0  25.0        10         7   86.0  71.0 NaN       14
# 3         4       20.0  45.0        11         0   66.0  65.0 NaN       14
# 5         6        2.5  77.5        10        11    NaN  41.0 NaN       14
#
#      margin  weight  res_win  res_place
# ...

# %%
df_cleaned.isna().sum()
# Out:
# horseName             0
# age                 297
# decimalPrice          0
# isFav                 0
# trainerName        2490
# jockeyName          101
# position              0
# positionL        783702
# dist            1001116
# weightSt              0
# weightLb              0
# RPR              760017
# TR              1460936
# OR              1538830
# runners               0
# margin                0
# weight                0
# res_win               0
# res_place             0
# dtype: int64

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3495138 entries, 0 to 4107314
# Data columns (total 19 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   horseName     object
#  1   age           float64
#  2   decimalPrice  float64
#  3   isFav         int64
#  4   trainerName   object
#  5   jockeyName    object
#  6   position      int64
#  7   positionL     float64
#  8   dist          float64
#  9   weightSt      int64
#  10  weightLb      int64
#  11  RPR           float64
#  12  TR            float64
#  13  OR            float64
#  14  runners       int64
#  15  margin        float64
#  16  weight        int64
#  17  res_win       float64
#  18  res_place     float64
# dtypes: float64(10), int64(6), object(3)
# memory usage: 533.3+ MB

# %%
df_cleaned['age']=df_cleaned['age'].fillna(df_cleaned['age'].mean())
df_cleaned['positionL']=df_cleaned['positionL'].fillna(df_cleaned['positionL'].mean())
df_cleaned['dist']=df_cleaned['dist'].fillna(df_cleaned['dist'].mean())
df_cleaned['RPR']=df_cleaned['RPR'].fillna(df_cleaned['RPR'].mean())
df_cleaned['TR']=df_cleaned['TR'].fillna(df_cleaned['TR'].mean())
df_cleaned['OR']=df_cleaned['OR'].fillna(df_cleaned['OR'].mean())
# Out:
# C:\Users\sairam\AppData\Local\Temp\ipykernel_14740\3866123848.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['age']=df_cleaned['age'].fillna(df_cleaned['age'].mean())
# C:\Users\sairam\AppData\Local\Temp\ipykernel_14740\3866123848.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['positionL']=df_cleaned['positionL'].fillna(df_cleaned['positionL'].mean())
# C:\Users\sairam\AppData\Local\Temp\ipykernel_14740\3866123848.py:3: SettingWithCopyWarning:
# ...

# %%
df_cleaned=df_cleaned.drop('margin',axis=1)

# %%
df_cleaned.isna().sum()
# Out:
# horseName          0
# age                0
# decimalPrice       0
# isFav              0
# trainerName     2490
# jockeyName       101
# position           0
# positionL          0
# dist               0
# weightSt           0
# weightLb           0
# RPR                0
# TR                 0
# OR                 0
# runners            0
# margin             0
# weight             0
# res_win            0
# res_place          0
# dtype: int64

# %%
df_cleaned=df_cleaned.dropna()

# %%
df_cleaned.head()
# Out:
#           horseName  age  decimalPrice  isFav      trainerName  jockeyName  \
# 0        Combermere  6.0      0.222222      0        R G Frost     J Frost
# 1     Royal Battery  6.0      0.090909      0       D H Barons     S Earle
# 2           Just So  7.0      0.029412      0      J D Roberts  S Burrough
# 3  Mandraki Shuffle  8.0      0.090909      0  Oliver Sherwood  M Richards
# 5         Yreka Bay  8.0      0.029412      0    J A C Edwards    W Irvine
#
#    position  positionL       dist  weightSt  weightLb         RPR    TR  \
# 0         1   4.985226  19.695534        11         0  111.000000  94.0
# 1         2  10.000000  19.695534        11         0  101.000000  88.0
# 2         3  15.000000  25.000000        10         7   86.000000  71.0
# 3         4  20.000000  45.000000        11         0   66.000000  65.0
# 5         6   2.500000  77.500000        10        11   72.455062  41.0
#
#          OR  runners  weight  res_win  res_place
# ...

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3492551 entries, 0 to 4107314
# Data columns (total 18 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   horseName     object
#  1   age           float64
#  2   decimalPrice  float64
#  3   isFav         int64
#  4   trainerName   object
#  5   jockeyName    object
#  6   position      int64
#  7   positionL     float64
#  8   dist          float64
#  9   weightSt      int64
#  10  weightLb      int64
#  11  RPR           float64
#  12  TR            float64
#  13  OR            float64
#  14  runners       int64
#  15  weight        int64
#  16  res_win       float64
#  17  res_place     float64
# dtypes: float64(9), int64(6), object(3)
# memory usage: 506.3+ MB

# %%
df_cleaned['age']=df_cleaned['age'].astype(int)
df_cleaned['RPR']=df_cleaned['RPR'].astype(int)
df_cleaned['TR']=df_cleaned['TR'].astype(int)
df_cleaned['OR']=df_cleaned['OR'].astype(int)
df_cleaned['res_win']=df_remove_column['res_win'].astype(int)
df_cleaned['res_place']=df_cleaned['res_place'].astype(int)

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3492551 entries, 0 to 4107314
# Data columns (total 18 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   horseName     object
#  1   age           int32
#  2   decimalPrice  float64
#  3   isFav         int64
#  4   trainerName   object
#  5   jockeyName    object
#  6   position      int64
#  7   positionL     float64
#  8   dist          float64
#  9   weightSt      int64
#  10  weightLb      int64
#  11  RPR           int32
#  12  TR            int32
#  13  OR            int32
#  14  runners       int64
#  15  weight        int64
#  16  res_win       int32
#  17  res_place     int32
# dtypes: float64(3), int32(6), int64(6), object(3)
# memory usage: 426.3+ MB

# %%
df_cleaned.isna().sum()
# Out:
# horseName       0
# age             0
# decimalPrice    0
# isFav           0
# trainerName     0
# jockeyName      0
# position        0
# positionL       0
# dist            0
# weightSt        0
# weightLb        0
# RPR             0
# TR              0
# OR              0
# runners         0
# weight          0
# res_win         0
# res_place       0
# dtype: int64

# %% [markdown]
# # categorical column is convert to numerical data with using ml LabelEncoder

# %%
# df_cleaned.to_csv("Horse_race_cleaned_data.csv",index=False)

# %%
df_cleaned=pd.read_csv(r"D:\jupyter folder\Horse_race_cleaned_data.csv")

# %%
from sklearn.preprocessing import LabelEncoder
model=LabelEncoder()
cols=['horseName','trainerName','jockeyName']
model=LabelEncoder()
for col in cols:
    df_cleaned[col]=model.fit_transform(df_cleaned[col])

# %%
df_cleaned.head()
# Out:
#    horseName  age  decimalPrice  isFav  trainerName  jockeyName  position  \
# 0      65141    6      0.222222      0        14423        3932         1
# 1     271717    6      0.090909      0         2570       15622         2
# 2     159650    7      0.029412      0         5876       15584         3
# 3     194130    8      0.090909      0        13242        6176         4
# 4     357845    8      0.029412      0         5744       16917         6
#
#    positionL       dist  weightSt  weightLb  RPR  TR  OR  runners  weight  \
# 0   4.985226  19.695534        11         0  111  94  80       14      69
# 1  10.000000  19.695534        11         0  101  88  80       14      69
# 2  15.000000  25.000000        10         7   86  71  80       14      66
# 3  20.000000  45.000000        11         0   66  65  80       14      69
# 4   2.500000  77.500000        10        11   72  41  80       14      68
#
#    res_win  res_place
# 0        1          1
# 1        0          1
# ...

# %%
df_cleaned['res_win'].value_counts()
# Out:
# res_win
# 0    3097812
# 1     394739
# Name: count, dtype: int64

# %%
df_cleaned.columns
# Out:
# Index(['horseName', 'age', 'decimalPrice', 'isFav', 'trainerName',
#        'jockeyName', 'position', 'positionL', 'dist', 'weightSt', 'weightLb',
#        'RPR', 'TR', 'OR', 'runners', 'weight', 'res_win', 'res_place'],
#       dtype='object')

# %% [markdown]
# # Apply SMOTE to balance the dataset

# %%
from imblearn.over_sampling import SMOTE
X=df_cleaned.drop(columns=['res_win'])
y=df_cleaned['res_win']

smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)
df_resampled = pd.concat([pd.DataFrame(X_resampled), pd.DataFrame(y_resampled, columns=['res_win'])], axis=1)

# %%
df_resampled['res_win'].value_counts()
# Out:
# res_win
# 1    3097812
# 0    3097812
# Name: count, dtype: int64

# %%
#df_resampled.to_csv("Horse_race_balanced_data.csv",index=False)

# %%
df_resampled=pd.read_csv(r"D:\jupyter folder\Horse_race_balanced_data.csv")

# %%
# Checking the Correlation using heatmap
import matplotlib.pyplot as plt
import seaborn as sns
df_resampled_corr= df_resampled.corr()
plt.figure(figsize=(20,10))
sns.heatmap(df_resampled_corr,annot= True, cmap="Greens", fmt=".2f")
plt.show()

# %% [markdown]
# # ○	Scatter plots, histograms, and box plots to visualize data distribution

# %%
# detecting the skewed columns using plot
def plot(df,column):
  #distplot
  plt.figure(figsize=(15,4))
  plt.subplot(1,3,1)
  sns.distplot(df[column])
  plt.title("distplot for"+" "+column)

  #histogram plot

  plt.subplot(1,3,2)
  sns.histplot(df, x= column, kde= True, bins=30,color="salmon")
  plt.title("histogram plot for"+" "+column)

  #boxplot

  plt.subplot(1,3,3)

  sns.boxplot(df, x=column)
  plt.title("Box plot for"+" "+column)

# %%
for i in df_resampled.columns:
    plot(df_resampled,i)
# Out:
# C:\Users\sairam\AppData\Local\Temp\ipykernel_14740\1049427475.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# C:\Users\sairam\AppData\Local\Temp\ipykernel_14740\1049427475.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# ...

# %%
# outlier columns are 
# 'age','decimalPrice','isFav','position','positionL','dist','weightSt','RPR','TR','OR','runners','weight'

# %%
def outlier(df_resampled,column):
  q1= df_resampled[column].quantile(0.25)
  q3= df_resampled[column].quantile(0.75)

  iqr= q3-q1

  upper_threshold= q3 + (1.5*iqr)
  lower_threshold= q1 - (1.5*iqr)

  df_resampled[column]= df_resampled[column].clip(lower_threshold, upper_threshold)

# %%
outlier_columns=['age','decimalPrice','isFav','position','positionL','dist','weightSt','RPR','TR','OR','runners','weight']
for j in outlier_columns:
    outlier(df_resampled,j)

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6195624 entries, 0 to 6195623
# Data columns (total 18 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   horseName     int64
#  1   age           float64
#  2   decimalPrice  float64
#  3   isFav         int64
#  4   trainerName   int64
#  5   jockeyName    int64
#  6   position      int64
#  7   positionL     float64
#  8   dist          float64
#  9   weightSt      int64
#  10  weightLb      int64
#  11  RPR           int64
#  12  TR            int64
#  13  OR            float64
#  14  runners       int64
#  15  weight        int64
#  16  res_place     int64
#  17  res_win       int64
# dtypes: float64(5), int64(13)
# memory usage: 850.8 MB

# %%
# after removing outliner

# %%
for i in df_resampled.columns:
    plot(df_resampled,i)
# Out:
# C:\Users\sairam\AppData\Local\Temp\ipykernel_8984\1049427475.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# C:\Users\sairam\AppData\Local\Temp\ipykernel_8984\1049427475.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# ...

# %%
df_resampled=df_resampled.drop('isFav',axis=1)

# %%
# Checking the correlation after the outlier recorrection
plt.figure(figsize=(20,10))
sns.heatmap(df_resampled.corr(), annot= True, cmap="Greens", fmt="0.2f")
plt.show()

# %%
# df_resampled.to_csv("Horse_race_balanced_data.csv",index=False)

# %%
df_resampled.describe().T
# Out:
#                   count           mean            std        min  \
# horseName     6195624.0  179713.747183  104086.920176   0.000000
# age           6195624.0       4.730107       2.068377  -1.500000
# decimalPrice  6195624.0       0.171506       0.133108   0.000799
# trainerName   6195624.0    8720.007365    5348.034433   0.000000
# jockeyName    6195624.0    8172.781779    6038.131206   0.000000
# position      6195624.0       4.301415       4.565782   0.000000
# positionL     6195624.0       4.275010       1.958616   0.250000
# dist          6195624.0      18.642986       3.039220  13.581699
# weightSt      6195624.0       9.186106       1.118354   5.000000
# weightLb      6195624.0       5.938344       3.852250   0.000000
# RPR           6195624.0      81.442549      25.236279  24.000000
# TR            6195624.0      57.676818      18.749021  24.000000
# OR            6195624.0      79.975708      12.365981  57.500000
# ...

# %%
df_resampled.head()
# Out:
#    horseName  age  decimalPrice  trainerName  jockeyName  position  positionL  \
# 0      65141  6.0      0.222222        14423        3932         1   4.985226
# 1     271717  6.0      0.090909         2570       15622         2   7.963065
# 2     159650  7.0      0.029412         5876       15584         3   7.963065
# 3     194130  8.0      0.090909        13242        6176         4   7.963065
# 4     357845  8.0      0.029412         5744       16917         6   2.500000
#
#         dist  weightSt  weightLb  RPR  TR    OR  runners  weight  res_place  \
# 0  19.695534        11         0  111  94  80.0       14      69          1
# 1  19.695534        11         0  101  88  80.0       14      69          1
# 2  23.363834        10         7   86  71  80.0       14      66          1
# 3  23.363834        11         0   66  65  80.0       14      69          0
# 4  23.363834        10        11   72  41  80.0       14      68          0
#
#    res_win
# 0        1
# 1        0
# ...

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,auc,roc_curve,confusion_matrix,classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
x=df_resampled.drop(['res_place','res_win'],axis=1)
y=df_resampled['res_win']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
models=[LogisticRegression(),DecisionTreeClassifier(),RandomForestClassifier(),KNeighborsClassifier()]

# %%
for model in models:
    model.fit(x_train,y_train)
    train_pred=model.predict(x_train)
    test_pred=model.predict(x_test)

    print(f"*************{type(model).__name__}************")
    print(f"Train Accuracy: {accuracy_score(y_train,train_pred)}")
    print(f"Train Precision: {precision_score(y_train,train_pred)}")
    print(f"Train Recall: {recall_score(y_train,train_pred)}")
    print(f"Train Precision: {f1_score(y_train,train_pred)}")
    print("...............................................")
    print(f"Test Accuracy: {accuracy_score(y_test,test_pred)}")
    print(f"Test Precision: {precision_score(y_test,test_pred)}")
    print(f"Test Recall: {recall_score(y_test,test_pred)}")
    print(f"Test Precision: {f1_score(y_test,test_pred)}")
# Out:
# C:\Users\sairam\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# *************LogisticRegression************
# Train Accuracy: 0.8865840586268654
# Train Precision: 0.8595157857362955
# Train Recall: 0.9241948833967666
# Train Precision: 0.890682670819387
# ...............................................
# Test Accuracy: 0.8867208715827701
# Test Precision: 0.8601638009511993
# Test Recall: 0.9237270499565238
# Test Precision: 0.8908129888414822
# *************DecisionTreeClassifier************
# ...

# %%
# Get the high accuracy using Hyperparameter Tuning method with using of the GridsearchCV

x_train, x_test, y_train, y_test= train_test_split(x,y, test_size= 0.2, random_state=42)

parameters= {"max_depth": [5, 10],
             "min_samples_split": [2,5],
             "min_samples_leaf": [1,2],
             "max_features": ['sqrt', 'log2']
             }

gridsearch= GridSearchCV(estimator= DecisionTreeClassifier(), param_grid= parameters, cv= 3, n_jobs= -1,verbose=1)
gridsearch.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [5, 10], 'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5]},
#              verbose=1)

# %%
gridsearch.best_score_
# Out:
# 0.9984747295368624

# %%
gridsearch.best_params_
# Out:
# {'max_depth': 10,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 2,
#  'min_samples_split': 5}

# %%
# Passing the best Hypertuning paramers in the ,
# RandomForest algorithm and check the accuracy for training and testing

# %%
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.2, random_state= 42)

model= DecisionTreeClassifier(max_depth=10, max_features= 'sqrt', min_samples_leaf=2, min_samples_split=5).fit(x_train,y_train)

y_pred_train= model.predict(x_train)
y_pred_test= model.predict(x_test)

#checking the accuracy_score for train and test

accuracy_train= accuracy_score(y_train, y_pred_train)
accuracy_test= accuracy_score(y_test, y_pred_test)

print("Accuracy score for Train and Test")
print("----------------------------------")
print("Accuracy_Train: ",accuracy_train)
print("Accuracy_Test: ",accuracy_test)
print("  ")
#confution matrics and the classification report for test

print("Confution_matrix for Test")
print("--------------------------")
print(confusion_matrix(y_true= y_test, y_pred= y_pred_test))
print(" ")
print("Classification_report for Test")
print("-------------------------------")
print(classification_report(y_true= y_test, y_pred= y_pred_test))
# Out:
# Accuracy score for Train and Test
# ----------------------------------
# Accuracy_Train:  0.9999729647882507
# Accuracy_Test:  0.9999717542620801
#
# Confution_matrix for Test
# --------------------------
# [[619943     24]
#  [    11 619147]]
#
# Classification_report for Test
# -------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    619967
#            1       1.00      1.00      1.00    619158
#
#     accuracy                           1.00   1239125
#    macro avg       1.00      1.00      1.00   1239125
# weighted avg       1.00      1.00      1.00   1239125

# %%
# Receiver Operating Characteristic (ROC) Curve and Area Under the Curve (AUC)

FP,TP,threshold= roc_curve(y_true= y_test, y_score=y_pred_test)
print(threshold)
print(FP)
print(TP)
print(" ")
auc_curve= auc(x=FP,y=TP)
print("auc_curve:",auc_curve)
# Out:
# [inf  1.  0.]
# [0.00000000e+00 3.87117379e-05 1.00000000e+00]
# [0.         0.99998223 1.        ]
#
# auc_curve: 0.9999717610995869

# %%
# create a plot for roc and auc curve
roc_point= {"ROC Curve (area)":round(auc_curve,2)}
plt.plot(FP,TP,label= roc_point)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.1])
plt.xlabel("False Positive")
plt.ylabel("True Positive")
plt.plot([0,1],[0,1],"k--")
plt.legend(loc= "lower right")
plt.show()

# %%
import numpy as np
import pickle

# %%
df_resampled.head()
# Out:
#    horseName  age  decimalPrice  trainerName  jockeyName  position  positionL  \
# 0      65141  6.0      0.222222        14423        3932         1   4.985226
# 1     271717  6.0      0.090909         2570       15622         2   7.963065
# 2     159650  7.0      0.029412         5876       15584         3   7.963065
# 3     194130  8.0      0.090909        13242        6176         4   7.963065
# 4     357845  8.0      0.029412         5744       16917         6   2.500000
#
#         dist  weightSt  weightLb  RPR  TR    OR  runners  weight  res_place  \
# 0  19.695534        11         0  111  94  80.0       14      69          1
# 1  19.695534        11         0  101  88  80.0       14      69          1
# 2  23.363834        10         7   86  71  80.0       14      66          1
# 3  23.363834        11         0   66  65  80.0       14      69          0
# 4  23.363834        10        11   72  41  80.0       14      68          0
#
#    res_win
# 0        1
# 1        0
# ...

# %% [markdown]
# # Testing my model with data

# %%
user_data = np.array([[65141, 6.0, 0.222222, 14423, 3932, 1, 4.985226, 19.695534, 11,0,111,94,80,14,69]])
y_pred_user= model.predict(user_data)
if y_pred_user == 1:
    print("Won")
else:
    print("Lose")
# Out:
# Won
# C:\Users\sairam\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
# finally my data predict 99.999% accuracy

# %% [markdown]
# # finally I am saved my classification Model

# %% [raw]
# #saving the model using the pickle
#
# with open("Horse_race_Classification_model.pkl","wb") as f:
#     pickle.dump(model,f)

# %%
with open(r"D:\jupyter folder\Horse_race_Classification_model.pkl","rb") as f1:
  class_model= pickle.load(f1)
